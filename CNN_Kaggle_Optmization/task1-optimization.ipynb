# %% [markdown]
# # ECBM E4040 Assignment 2 - Task 1: Optimization
#
# In this task, we introduce multiple SGD-based optimization methods. As you have learned from the last assignment, SGD is an efficient method to update parameters. However, to make SGD perform well, we need to find an appropriate learning rate and a good initial value. Otherwise, the network will get stuck if learning rate is small, or it will diverge if the learning rate is too large. In reality, since we have no prior knowledge about the training data, it is not trivial to find a good learning rate manually. Also, when the network becomes deeper, for each layer we may need to set a different learning rate, and that will again increase the development workload. Obviously, this is not a good direction.
#
# Another common problem is the lack of sufficient training data. This can make our training get stuck when using the naive SGD method.
#
# So, **how to set a good learning rate?** You are going to experiment with **SGD with momentum**, **RMSProp**, **Adam** and make comparisons.
#
# All of these optimizers are adaptive learning rate methods. Here is a useful link: http://ruder.io/optimizing-gradient-descent/.

# %%
% matplotlib inline
% load_ext autoreload
% autoreload 2

# Import modules
from __future__ import print_function
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from ecbm4040.cifar_utils import load_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load CIFAR 10
#
# Here we use a small dataset with only 2500 samples to simulate "lack-of-data" situation.

# %%
# Load the raw CIFAR-10 data.
X_train, y_train, X_test, y_test = load_data()
X_val = X_train[:500,:]
y_val = y_train[:500]
X_train = X_train[500:2500,:]
y_train = y_train[500:2500]

mean_image = np.mean(X_train, axis=0).astype(np.float32)
X_train = X_train.astype(np.float32) - mean_image
X_val = X_val.astype(np.float32) - mean_image

# We've vectorized the data for you. That is, we flatten the 32×32×3 images into 1×3072 Numpy arrays.
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
# Out:
# ./data/cifar-10-python.tar.gz already exists. Begin extracting...
# Training data shape:  (2000, 3072)
# Training labels shape:  (2000,)
# Validation data shape:  (500, 3072)
# Validation labels shape:  (500,)

# %% [markdown]
# ## Part 1: Implement Optimizers
#
# Here we provide an MLP code snippet for testing.

# %%
from ecbm4040.neuralnets.mlp import MLP

# %% [markdown]
# ### Original SGD (for comparison purpose only)

# %%
from ecbm4040.optimizers import SGDOptim

model = MLP(input_dim=3072, hidden_dims=[100, 100], num_classes=10, weight_scale=1e-3, l2_reg=0.0)
optimizer = SGDOptim()
hist_sgd = optimizer.train(model, X_train, y_train, X_val, y_val, num_epoch=30, batch_size=200, learning_rate=1e-2, learning_decay=0.95, verbose=False, record_interval=1)
# Out:
# number of batches for training: 10
# epoch 1: valid acc = 0.154, new learning rate = 0.0095
# epoch 2: valid acc = 0.156, new learning rate = 0.009025
# epoch 3: valid acc = 0.158, new learning rate = 0.00857375
# epoch 4: valid acc = 0.16, new learning rate = 0.0081450625
# epoch 5: valid acc = 0.156, new learning rate = 0.007737809374999999
# epoch 6: valid acc = 0.158, new learning rate = 0.007350918906249998
# epoch 7: valid acc = 0.172, new learning rate = 0.006983372960937498
# epoch 8: valid acc = 0.164, new learning rate = 0.006634204312890623
# epoch 9: valid acc = 0.188, new learning rate = 0.006302494097246091
# epoch 10: valid acc = 0.19, new learning rate = 0.005987369392383786
# epoch 11: valid acc = 0.196, new learning rate = 0.005688000922764597
# epoch 12: valid acc = 0.2, new learning rate = 0.005403600876626367
# epoch 13: valid acc = 0.198, new learning rate = 0.005133420832795048
# epoch 14: valid acc = 0.202, new learning rate = 0.0048767497911552955
# epoch 15: valid acc = 0.198, new learning rate = 0.00463291230159753
# epoch 16: valid acc = 0.196, new learning rate = 0.0044012666865176535
# epoch 17: valid acc = 0.202, new learning rate = 0.004181203352191771
# epoch 18: valid acc = 0.2, new learning rate = 0.003972143184582182
# epoch 19: valid acc = 0.198, new learning rate = 0.0037735360253530726
# epoch 20: valid acc = 0.2, new learning rate = 0.0035848592240854188
# epoch 21: valid acc = 0.2, new learning rate = 0.0034056162628811476
# epoch 22: valid acc = 0.204, new learning rate = 0.0032353354497370902
# epoch 23: valid acc = 0.202, new learning rate = 0.0030735686772502355
# epoch 24: valid acc = 0.206, new learning rate = 0.0029198902433877237
# epoch 25: valid acc = 0.204, new learning rate = 0.0027738957312183374
# epoch 26: valid acc = 0.202, new learning rate = 0.0026352009446574203
# epoch 27: valid acc = 0.202, new learning rate = 0.002503440897424549
# epoch 28: valid acc = 0.202, new learning rate = 0.0023782688525533216
# epoch 29: valid acc = 0.2, new learning rate = 0.0022593554099256553
# epoch 30: valid acc = 0.198, new learning rate = 0.0021463876394293723

# %% [markdown]
# ### SGD + Momentum
#
# <span style="color:red">__TODO:__</span> Edit **SGDmomentumOptim** in __./ecbm4040/optimizers.py__

# %%
from ecbm4040.optimizers import SGDmomentumOptim

model = MLP(input_dim=3072, hidden_dims=[100, 100], num_classes=10, l2_reg=0.0, weight_scale=1e-3)
optimizer = SGDmomentumOptim(model, momentum=0.8)
hist_sgd_momentum = optimizer.train(model, X_train, y_train, X_val, y_val, 
                                         num_epoch=30, batch_size=200, learning_rate=1e-2, 
                                         learning_decay=0.95, verbose=False, record_interval=1)
# Out:
# number of batches for training: 10
# epoch 1: valid acc = 0.116, new learning rate = 0.0095
# epoch 2: valid acc = 0.122, new learning rate = 0.009025
# epoch 3: valid acc = 0.168, new learning rate = 0.00857375
# epoch 4: valid acc = 0.166, new learning rate = 0.0081450625
# epoch 5: valid acc = 0.192, new learning rate = 0.007737809374999999
# epoch 6: valid acc = 0.174, new learning rate = 0.007350918906249998
# epoch 7: valid acc = 0.188, new learning rate = 0.006983372960937498
# epoch 8: valid acc = 0.194, new learning rate = 0.006634204312890623
# epoch 9: valid acc = 0.196, new learning rate = 0.006302494097246091
# epoch 10: valid acc = 0.198, new learning rate = 0.005987369392383786
# epoch 11: valid acc = 0.196, new learning rate = 0.005688000922764597
# epoch 12: valid acc = 0.196, new learning rate = 0.005403600876626367
# epoch 13: valid acc = 0.198, new learning rate = 0.005133420832795048
# epoch 14: valid acc = 0.2, new learning rate = 0.0048767497911552955
# epoch 15: valid acc = 0.2, new learning rate = 0.00463291230159753
# epoch 16: valid acc = 0.202, new learning rate = 0.0044012666865176535
# epoch 17: valid acc = 0.206, new learning rate = 0.004181203352191771
# epoch 18: valid acc = 0.204, new learning rate = 0.003972143184582182
# epoch 19: valid acc = 0.206, new learning rate = 0.0037735360253530726
# epoch 20: valid acc = 0.21, new learning rate = 0.0035848592240854188
# epoch 21: valid acc = 0.212, new learning rate = 0.0034056162628811476
# epoch 22: valid acc = 0.212, new learning rate = 0.0032353354497370902
# epoch 23: valid acc = 0.204, new learning rate = 0.0030735686772502355
# epoch 24: valid acc = 0.204, new learning rate = 0.0029198902433877237
# epoch 25: valid acc = 0.198, new learning rate = 0.0027738957312183374
# epoch 26: valid acc = 0.202, new learning rate = 0.0026352009446574203
# epoch 27: valid acc = 0.202, new learning rate = 0.002503440897424549
# epoch 28: valid acc = 0.206, new learning rate = 0.0023782688525533216
# epoch 29: valid acc = 0.208, new learning rate = 0.0022593554099256553
# epoch 30: valid acc = 0.204, new learning rate = 0.0021463876394293723

# %% [markdown]
# ### RMSprop
#
# <span style="color:red">__TODO:__</span> Edit **RMSpropOptim** in **./ecbm4040/optimizers.py**

# %%
from ecbm4040.optimizers import RMSpropOptim

model = MLP(input_dim=3072, hidden_dims=[100, 100], num_classes=10, l2_reg=0.0, weight_scale=1e-3)
optimizer = RMSpropOptim(model)
hist_rmsprop = optimizer.train(model, X_train, y_train, X_val, y_val, 
                               num_epoch=30, batch_size=200, learning_rate=1e-3, 
                               learning_decay=0.95, verbose=False, record_interval=1)
# Out:
# number of batches for training: 10
# epoch 1: valid acc = 0.082, new learning rate = 0.00095
# epoch 2: valid acc = 0.074, new learning rate = 0.0009025
# epoch 3: valid acc = 0.074, new learning rate = 0.000857375
# epoch 4: valid acc = 0.074, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.076, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.054, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.068, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.074, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.08, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.14, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.136, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.166, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.17, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.178, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.202, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.22, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.214, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.214, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.228, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.238, new learning rate = 0.0003584859224085418
# epoch 21: valid acc = 0.256, new learning rate = 0.0003405616262881147
# epoch 22: valid acc = 0.278, new learning rate = 0.00032353354497370894
# epoch 23: valid acc = 0.238, new learning rate = 0.00030735686772502346
# epoch 24: valid acc = 0.266, new learning rate = 0.00029198902433877225
# epoch 25: valid acc = 0.28, new learning rate = 0.00027738957312183364
# epoch 26: valid acc = 0.278, new learning rate = 0.0002635200944657419
# epoch 27: valid acc = 0.288, new learning rate = 0.0002503440897424548
# epoch 28: valid acc = 0.256, new learning rate = 0.00023782688525533205
# epoch 29: valid acc = 0.304, new learning rate = 0.00022593554099256544
# epoch 30: valid acc = 0.302, new learning rate = 0.00021463876394293716

# %% [markdown]
# ### Adam
#
# <span style="color:red">__TODO:__</span> Edit **AdamOptim** in **./ecbm4040/optimizers.py**

# %%
from ecbm4040.optimizers import AdamOptim

model = MLP(input_dim=3072, hidden_dims=[100, 100], num_classes=10, l2_reg=0.0, weight_scale=1e-3)
optimizer = AdamOptim(model)
hist_adam = optimizer.train(model, X_train, y_train, X_val, y_val, 
                            num_epoch=30, batch_size=200, learning_rate=1e-3, 
                            learning_decay=0.95, verbose=False, record_interval=1)
# Out:
# number of batches for training: 10
# epoch 1: valid acc = 0.118, new learning rate = 0.00095
# epoch 2: valid acc = 0.166, new learning rate = 0.0009025
# epoch 3: valid acc = 0.184, new learning rate = 0.000857375
# epoch 4: valid acc = 0.158, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.192, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.246, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.246, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.25, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.248, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.27, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.3, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.292, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.308, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.31, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.326, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.306, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.318, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.338, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.336, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.344, new learning rate = 0.0003584859224085418
# epoch 21: valid acc = 0.35, new learning rate = 0.0003405616262881147
# epoch 22: valid acc = 0.37, new learning rate = 0.00032353354497370894
# epoch 23: valid acc = 0.348, new learning rate = 0.00030735686772502346
# epoch 24: valid acc = 0.338, new learning rate = 0.00029198902433877225
# epoch 25: valid acc = 0.34, new learning rate = 0.00027738957312183364
# epoch 26: valid acc = 0.364, new learning rate = 0.0002635200944657419
# epoch 27: valid acc = 0.37, new learning rate = 0.0002503440897424548
# epoch 28: valid acc = 0.376, new learning rate = 0.00023782688525533205
# epoch 29: valid acc = 0.342, new learning rate = 0.00022593554099256544
# epoch 30: valid acc = 0.33, new learning rate = 0.00021463876394293716

# %% [markdown]
# ## Part 2: Comparison
#
# <span style="color:red">__TODO:__</span> Run the following cells, which plot the loss curves of different optimizers. Describe your results, and discuss your understandings of these optimizers, such as their advantages/disadvantages and when to use them.

# %%
loss_hist_sgd, train_acc_hist_sgd, val_acc_hist_sgd = hist_sgd
loss_hist_momentum, train_acc_hist_momentum, val_acc_hist_momentum = hist_sgd_momentum
loss_hist_rmsprop, train_acc_hist_rmsprop, val_acc_hist_rmsprop = hist_rmsprop
loss_hist_adam, train_acc_hist_adam, val_acc_hist_adam = hist_adam

# %%
# Plot training error curve of optimizers
plt.plot(loss_hist_sgd, label="sgd")
plt.plot(loss_hist_momentum, label="momentum")
plt.plot(loss_hist_rmsprop, label="rmsprop")
plt.plot(loss_hist_adam, label="adam")
plt.legend()
plt.show()

# %%
# Plot training accuracy curve of optimizers
plt.plot(train_acc_hist_sgd, label="sgd")
plt.plot(train_acc_hist_momentum, label="momentum")
plt.plot(train_acc_hist_rmsprop, label="rmsprop")
plt.plot(train_acc_hist_adam, label="adam")
plt.legend()
plt.show()

# %%
# Plot validation accuracy curve of optimizers
plt.plot(val_acc_hist_sgd, label="sgd")
plt.plot(val_acc_hist_momentum, label="momentum")
plt.plot(val_acc_hist_rmsprop, label="rmsprop")
plt.plot(val_acc_hist_adam, label="adam")
plt.legend()
plt.show()

# %% [markdown]
# Advantages and disadvantages:
#
# It can be observed that SGD, SGD with momentum and RMSprop have lower accuracy and higher loss compared to ADAM.
#
# Advantages based on understandings:
#
#
# SGD updates the movement of each step based on the current values. Hence it is unstable in movement directions.
# SGD with momentum brings an improvement here as momentum provides a "direction check" based on previous values.
# RMS prop adjusts the learning rates based on past gradients and adjusts weights more finely than previous methods.
# ADAM, to update learning rate uses a moving average method on moments of gradients to update weights.
# Due to this process, ADAM shows higer accuracy and lower loss.
#
# It can be observed that methods which adjust more finely show a better accuracy.
#
# Disadvatages:
# FOR SGD, and SGD wiht momentum the learning rate has to be chosen very carefully. The general disadvantages of more complex algorithms like RMS prop and ADAM is the usage of space to store mroe variables and time complexity. But these are not as important compared ot the advantages.
