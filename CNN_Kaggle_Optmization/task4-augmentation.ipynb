# %% [markdown]
# # ECBM E4040 - Assignment 2 - Task 4: Data Augmentation
#
# One important factor in neural network training is the size of the traininig set. Since it is often not possible to get a clean and large enough dataset for training, one way to improve the network's robustness and generalization ability is to create 'fake' data by injecting random noise or doing random transformations on the available data. A technique which implements this strategy is called __data augmentation__, and has shown to be very effective.
#
# One thing to remember, when you augment your data, is to never change the correct label of a sample. For example, for hand-written digit dataset, flipping a letter 'b' ends up looking like a letter 'd', but you must keep the label for 'b'. So please choose the best augmentation methods for your dataset.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# Import modules
from __future__ import print_function
import numpy as np
from ecbm4040.cifar_utils import load_data
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
X_train, y_train, X_test, y_test = load_data()

num_train = 49000
num_val = 1000
num_test = 10000
num_dev = 128

# The development set is used for augmentation practices.
mask = np.random.choice(num_train, num_dev, replace=False)
X_dev = X_train[mask]
y_dev = y_train[mask]

# Seperate Training set into a training set and a validation set
X_val = X_train[num_train:]
y_val = y_train[num_train:]
X_train = X_train[:num_train]
y_train = y_train[:num_train]

print(X_train.shape, X_val.shape, X_test.shape, X_dev.shape)
# Out:
# ./data/cifar-10-python.tar.gz already exists. Begin extracting...
# (49000, 3072) (1000, 3072) (10000, 3072) (128, 3072)

# %% [markdown]
# ## Part 1: Visualization

# %% [markdown]
# ### Visualize some original images
#
# <span style="color:red">__TODO:__</span> Use Pyplot to draw any 16 samples from the __development set__ in a 4-by-4 grid.
#
# __Hint__: The original data is vectorized, you need to find a way to reshape it into 32*32 RGB image.

# %%
# YOUR CODE HERE
X_dev_reshaped = X_dev.reshape([128,3,32,32]).transpose((0,2,3,1))

li_index=np.random.randint(0,127,16)
images=[]
for i in range(16):
    images.append(np.reshape(X_dev_reshaped[li_index[i],:],(32,32,3)))

f, axarr = plt.subplots(4,4,figsize=(8,8))
for i in range(4):
    for j in range(4):
        axarr[i][j].imshow(images[4*i+j])

# %% [raw]
# ## Part 2: Automatic batch generator

# %% [markdown]
# We want you to create an automatic image generator that does several kinds of data augmentations, and produces a batch of data consisting of random samples every time you call it.
#
# <span style="color:red">__TODO__:</span> Finish the functions of class __ImageGenerator__ in __ecbm4040/image_generator.py__. The code is fully commented with instructions.
#
# __Hint__: The python keywords __yield__ and __next__ can help you do some tricks.

# %%
from ecbm4040.image_generator import ImageGenerator

# %% [markdown]
# <span style="color:red">__TODO__:</span> Create an ImageGenerator object using the __development set__, and use __show__ function to plot the top 16 original images.

# %%
# YOUR CODE HERE

img=ImageGenerator(X_dev_reshaped,y_dev)
img.show()

# %% [markdown]
# ### Translation
#
# <span style="color:red">__TODO:__</span> Translate the original __development set__ by several pixels in both directions, and plot the top 16 images like you just did.

# %%
# YOUR CODE HERE
img.translate(16,16)
img.show()

# %% [markdown]
# ### Rotation
#
# <span style="color:red">__TODO:__</span> Rotate the original __development set__ by several degrees, and plot the top 16 images like you just did.

# %%
# YOUR CODE HERE
img_1=ImageGenerator(X_dev_reshaped,y_dev)
img_1.rotate(90.0)
img_1.show()

# %% [markdown]
# ### Flipping (horizontal and vertical)
#
# <span style="color:red">__TODO:__</span> Flip the original __development set__ as you like (horizontal, vertical, or both), and plot the top 16 images like you just did.

# %%
# YOUR CODE HERE
img_2=ImageGenerator(X_dev_reshaped,y_dev)
img_2.flip("v")
img_2.show()

# %% [markdown]
# ### Add Noise
#
# <span style="color:red">__TODO:__</span> Inject random noise into the original __development set__, and plot the top 16 images like you just did.

# %%
# YOUR CODE HERE
img_4=ImageGenerator(X_dev_reshaped,y_dev)
img_4.add_noise(0.2,20)
img_4.show()

# %% [markdown]
# ## Part 3: Data Augmentation + LeNet
#
# <span style="color:red">__TODO__:</span> Now that you have your own data generator. At the end of __ecbm4040/neuralnets/cnn.py__, there is a not-implemented function __my_training_task4()__. Copy the __my_training()__ function above and modify it so that it uses your data generator for training. Train the network again - whether you see and improvement or a drop, record it and analyze why.

# %%
# YOUR CODE HERE
import tensorflow as tf
from ecbm4040.neuralnets.cnn import my_training_task4
tf.reset_default_graph()
my_training_task4(X_train, y_train, X_val, y_val, 
         conv_featmap=[40,10],
         fc_units=[100,10],
         conv_kernel_size=[5,5],
         pooling_size=[2,2],
         l2_norm=0.01,
         seed=235,
         learning_rate=1e-3,
         epoch=20,
         batch_size=100,
         verbose=False,
         pre_trained_model=None,pro=1.0)
# Out:
# Building my LeNet. Parameters:
# conv_featmap=[40, 10]
# fc_units=[100, 10]
# conv_kernel_size=[5, 5]
# pooling_size=[2, 2]
# l2_norm=0.01
# seed=235
# learning_rate=0.001
# number of batches for training: 1960
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 14.700000000000003%
# Best validation accuracy! iteration:200 accuracy: 16.299999999999997%
# Best validation accuracy! iteration:300 accuracy: 20.299999999999997%
# Best validation accuracy! iteration:500 accuracy: 22.799999999999997%
# Best validation accuracy! iteration:600 accuracy: 34.8%
# Best validation accuracy! iteration:700 accuracy: 35.3%
# Best validation accuracy! iteration:800 accuracy: 37.9%
# Best validation accuracy! iteration:1000 accuracy: 43.2%
# Best validation accuracy! iteration:1100 accuracy: 49.0%
# Best validation accuracy! iteration:1200 accuracy: 53.8%
# Best validation accuracy! iteration:1300 accuracy: 54.7%
# Best validation accuracy! iteration:1400 accuracy: 57.3%
# Best validation accuracy! iteration:1600 accuracy: 60.3%
# Best validation accuracy! iteration:1800 accuracy: 62.9%
# Best validation accuracy! iteration:1900 accuracy: 64.0%
# epoch 2
# Best validation accuracy! iteration:3300 accuracy: 64.1%
# Best validation accuracy! iteration:3400 accuracy: 65.4%
# Best validation accuracy! iteration:3600 accuracy: 65.5%
# Best validation accuracy! iteration:3900 accuracy: 67.6%
# epoch 3
# Best validation accuracy! iteration:5700 accuracy: 68.5%
# Best validation accuracy! iteration:5800 accuracy: 68.6%
# epoch 4
# Best validation accuracy! iteration:7300 accuracy: 68.9%
# Best validation accuracy! iteration:7600 accuracy: 69.5%
# Best validation accuracy! iteration:7700 accuracy: 69.8%
# epoch 5
# Best validation accuracy! iteration:9500 accuracy: 71.9%
# epoch 6
# epoch 7
# epoch 8
# Best validation accuracy! iteration:15600 accuracy: 72.4%
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# Best validation accuracy! iteration:35100 accuracy: 72.6%
# Best validation accuracy! iteration:35200 accuracy: 73.0%
# epoch 19
# epoch 20
# Best validation accuracy! iteration:39200 accuracy: 74.1%
# Traning ends. The best valid accuracy is 74.1. Model named lenet_1509837170.
